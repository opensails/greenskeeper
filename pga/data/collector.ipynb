# %%
import json
import pandas as pd

# %%
base = 'https://www.pgatour.com'

# %%
with open('C:/Users/Austin/Documents/PythonProjects/Golf/pga/all_links.json', 'r') as stats:
    data = json.load(stats)

# %%
for stat_page in data:
    link = stat_page['link']
    page_name = stat_page['name']
    print(pd.read_html(base+link)[1])
# Out:
# RANK THIS WEEK RANK LAST WEEK           PLAYER NAME  ROUNDS  AVERAGE  \
# 0                1            NaN        Tyrrell Hatton      16    1.416
# 1                2              1           Boo Weekley      14    1.294
# 2                3              3          Rory McIlroy      24    1.216
# 3                4              5       Collin Morikawa      44    1.194
# 4                5              4         Marc Leishman      33    1.099
# ..             ...            ...                   ...     ...      ...
# 226            227            225          Ryo Ishikawa      14   -1.313
# 227            228            226           Derek Ernst      14   -1.429
# 228            229            221  Jazz Janewattananond      18   -1.494
# 229            230            227         Kevin Stadler      20   -1.642
# 230            231            228        Martin Trainer      34   -2.070
#
#      TOTAL SG:APP  MEASURED ROUNDS
# 0          11.324                8
# ...
