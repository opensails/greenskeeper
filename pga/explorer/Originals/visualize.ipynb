# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pprint
import seaborn as sns

# %%
data = pd.read_csv('fulldata.csv')

# %%
for key in data.keys():
    print(key)
# Out:
# player
# Scoring Average (Actual)-AVG
# Putting from 5-15'-ROUNDS
# Putting from 5-15'-% MADE
# Putting from 5-15'-ATTEMPTS
# Putting from 5-15'-PUTTS MADE
# Putts per Round - Round 1-AVG
# Putts per Round - Round 1-TOTAL PUTTS
# Putts per Round - Round 1-TOTAL ROUNDS
# Average Distance of Putts made-ROUNDS
# Average Distance of Putts made-AVG
# Average Distance of Putts made-TOTAL DIST (INCHES)
# Average Distance of Putts made-TOTAL ROUNDS
# Average Distance of Putts made-AVG DIST
# Average Distance of Putts made-BEST ROUND
# Putting from Inside 5'-ROUNDS
# Putting from Inside 5'-%
# Putting from Inside 5'-ATTEMPTS
# Putting from Inside 5'-PUTTS MADE
# 3-Putts per Round-ROUNDS
# 3-Putts per Round-AVG
# 3-Putts per Round-TOTAL 3 PUTTS
# 3-Putts per Round-TOTAL ROUNDS
# Putting from 4-8'-ROUNDS
# Putting from 4-8'-% MADE
# Putting from 4-8'-ATTEMPTS
# Putting from 4-8'-PUTTS MADE
# Average Putting Distance - All 1 putts-ROUNDS
# Average Putting Distance - All 1 putts-AVG
# ...

# %%
sns.regplot(x=data['Scoring Average (Actual)-AVG'], y=data['SG: Off-the-Tee-TOTAL SG:OTT'])

# %%
(data)[50:].corr()
# Out:
#                                           Scoring Average (Actual)-AVG  \
# Scoring Average (Actual)-AVG                                  1.000000
# Putting from 5-15'-ROUNDS                                    -0.331678
# Putting from 5-15'-% MADE                                    -0.218765
# Putting from 5-15'-ATTEMPTS                                  -0.338835
# Putting from 5-15'-PUTTS MADE                                -0.348347
# ...                                                                ...
# Proximity to Hole (ARG)-ROUNDS                               -0.331678
# Proximity to Hole (ARG)-# OF SHOTS                           -0.285356
# Proximity to Hole (ARG)-SCRAMBLING RANK                       0.583119
# Scrambling Rough (RTP Score)-ROUNDS                          -0.331678
# Scrambling Rough (RTP Score)-TOTAL HOLES                     -0.053948
#
#                                           Putting from 5-15'-ROUNDS  \
# ...
